# %% [markdown]
# <a href="https://colab.research.google.com/github/darehanthe8955-jpg/Customer-Churn-Analysis/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

# %%
import pandas as pd

df = pd.read_excel("churn_data_large.xlsx")
df

# %%
df.info()
df.describe()

# %%
df.isnull().sum()

# %%
df["TotalCharges"] = df["TotalCharges"].dropna()
df

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"] , errors = "coerce")
df

# %%
df.isnull().sum()

# %%
df.dropna(inplace = True)
df

# %%
df.drop_duplicates()
df.info()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot( x = "Churn" , data = df)
plt.savefig("Churn_distribution.png", dpi=300, bbox_inches='tight')

plt.show()
df

# %%
df["Churn"].value_counts(normalize =True )

# %%
sns.countplot(x = "Contract"  , hue = "Churn" , data = df)
plt.savefig("contract_Churn.png", dpi=300, bbox_inches='tight')
plt.show()
df

# %%
sns.boxplot(x = "tenure" , hue = "Churn" , data = df)
plt.savefig("tenure_Churn.png", dpi=300, bbox_inches='tight')
plt.show()
df

# %%
sns.histplot(x = "MonthlyCharges" , hue  = "Churn" , data = df)
plt.savefig("Monthly_charges_Churn.png", dpi=300, bbox_inches='tight')
plt.show()
df

# %%
sns.countplot(x = "PaymentMethod" ,  hue = "Churn" , data = df)
plt.savefig("paymentMethod_Churn.png", dpi=300, bbox_inches='tight')

plt.show()
df

# %%
df.drop("customerID"  ,axis = 1)
df

# %%
df = pd.get_dummies(df, drop_first = True)
df

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Churn_Yes', axis=1)
y = df['Churn_Yes']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
df

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %%
importance = pd.Series(model.coef_[0], index=X.columns)
importance.sort_values(ascending=False).head(10)

# %%
import pandas as pd

results = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

sns.countplot(x='Actual', hue='Predicted', data=results)
plt.title("Actual vs Predicted")
plt.savefig("Actual_vs_Predicted.png" , dpi = 300)
plt.show()
